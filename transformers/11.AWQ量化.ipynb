# %%
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer

model_path = "/home/hengzq/workspace/modelscope/models/opt-2.7b"

quant_config = {
    "zero_point": True,
    "q_group_size": 128,
    "w_bit": 4,
    "version": "GEMM"
}

model = AutoAWQForCausalLM.from_pretrained(model_path, trust_remote_code = True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[9], line 13
#       4 model_path = "/home/hengzq/workspace/modelscope/models/opt-2.7b"
#       6 quant_config = {
#       7     "zero_point": True,
#       8     "q_group_size": 128,
#       9     "w_bit": 4,
#      10     "version": "GEMM"
#      11 }
# ---> 13 model = AutoAWQForCausalLM.from_pretrained(model_path, trust_remote_code = True)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/awq/models/auto.py:74, in AutoAWQForCausalLM.from_pretrained(self, model_path, trust_remote_code, safetensors, device_map, download_kwargs, **model_init_kwargs)
#      60 @classmethod
#      61 def from_pretrained(
#      62     self,
#    (...)
#      68     **model_init_kwargs,
#      69 ) -> BaseAWQForCausalLM:
#      70     model_type = check_and_get_model_type(
# ...

# %%
# 加载模型
model = AutoAWQForCausalLM.from_pretrained(model_path, trust_remote_code = True)
# tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code = True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 加载模型
# ----> 2 model = AutoAWQForCausalLM.from_pretrained(model_path, trust_remote_code = True)
#       3 # tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code = True)
#
# File ~/anaconda3/envs/py310/lib/python3.10/site-packages/awq/models/auto.py:74, in AutoAWQForCausalLM.from_pretrained(self, model_path, trust_remote_code, safetensors, device_map, download_kwargs, **model_init_kwargs)
#      60 @classmethod
#      61 def from_pretrained(
#      62     self,
#    (...)
#      68     **model_init_kwargs,
#      69 ) -> BaseAWQForCausalLM:
#      70     model_type = check_and_get_model_type(
#      71         model_path, trust_remote_code, **model_init_kwargs
#      72     )
# ---> 74     return AWQ_CAUSAL_LM_MODEL_MAP[model_type].from_pretrained(
#      75         model_path,
# ...
